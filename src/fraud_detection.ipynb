# %% [markdown]
# # Credic Card Fraud

# %% [markdown]
# Este notebook tem como objetivo treinar e avaliar um modelo de classificação binária utilizando o dataset público de detecção de fraudes em transações de cartão de crédito (Kaggle – Credit Card Fraud Detection).
#
# O dataset contém 284.807 transações reais, das quais apenas 492 são fraudes (uma relação muito parecida com o projeto que estamos fazendo no CREA), configurando um problema desbalanceado. As variáveis principais são:
#
# * V1–V28: features anonimizadas via PCA;
# * Time e Amount: tempo e valor da transação;
# * Class rótulo binário (0 = transação legítima, 1 = fraude).
#
# O modelo implementado é um Sequential em Keras com uma única camada `Dense` e ativação `sigmoid`, equivalente a uma regressão logística. O treinamento é feito com:
#
# * Otimizador: Adam
# * Função de perda: Binary Crossentropy
# * Métricas: Accuracy e F1-score
#
# Após o treino (50 épocas, batch size = 10), o modelo é avaliado no conjunto de teste, reportando accuracy e F1-score O projeto discute o impacto do desbalanceamento e apresenta possíveis melhorias como ajuste de threshold, uso de class_weight, reamostragem e métricas mais robustas como AUC-PR.
#
# ## Modo de uso:
# Como o arquivo de Fraude é muito grande, ele não foi anexadao nesse notebook. Caso queira rodar o código baixe o arquivo .zip em https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud e coloque o arquivo dentro da pasta [data](./data/).

# %%
import numpy as np
import pandas as pd
import zipfile, pathlib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
pathlib.Path("data").mkdir(exist_ok=True)
with zipfile.ZipFile("data/creditcardfraud.zip") as z:
    z.extractall("data")

# Agora o CSV estará em data/creditcard.csv
import pandas as pd
df = pd.read_csv("data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#separar X/y
y = df["Class"].values.astype(np.int32)
X = df.drop(columns=["Class"]).copy()

# %%
#padronizar 'Time' e 'Amount' (V1–V28 já são PCA-normalizados)
scaler = StandardScaler()
X[["Time", "Amount"]] = scaler.fit_transform(X[["Time", "Amount"]])

X = X.values

# %%
#split estratificado (desbalanceamento!)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42
)

# %%
#métrica F1 custom para Keras (acumulada por época)
class F1Score(keras.metrics.Metric):
    def __init__(self, threshold=0.5, name="f1", **kwargs):
        super().__init__(name=name, **kwargs)
        self.threshold = threshold
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.fp = self.add_weight(name="fp", initializer="zeros")
        self.fn = self.add_weight(name="fn", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred > self.threshold, tf.float32)
        tp = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true,1), tf.equal(y_pred,1)), tf.float32))
        fp = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true,0), tf.equal(y_pred,1)), tf.float32))
        fn = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_true,1), tf.equal(y_pred,0)), tf.float32))
        self.tp.assign_add(tp)
        self.fp.assign_add(fp)
        self.fn.assign_add(fn)

    def result(self):
        precision = self.tp / (self.tp + self.fp + keras.backend.epsilon())
        recall = self.tp / (self.tp + self.fn + keras.backend.epsilon())
        return 2.0 * (precision * recall) / (precision + recall + keras.backend.epsilon())

    def reset_states(self):
        for var in self.variables:
            var.assign(0.0)

# %%
#class weights para combater o desbalanceamento
classes = np.unique(y_train)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
class_weights = {int(c): float(w) for c, w in zip(classes, weights)}

# %%
#modelo sequencial com 1 Dense(sigmoid)
model = keras.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(1, activation="sigmoid"),
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", F1Score()]  # accuracy + F1 custom
)

# %%
#treina o modeloo por 50 épocas, batch_size=10
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=10,
    validation_split=0.1,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9828 - f1: 0.0169 - loss: 0.1441 - val_accuracy: 0.9788 - val_f1: 0.0179 - val_loss: 0.1054
# Epoch 2/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9776 - f1: 0.0158 - loss: 0.1615 - val_accuracy: 0.9818 - val_f1: 0.0200 - val_loss: 0.0996
# Epoch 3/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 47s 2ms/step - accuracy: 0.9815 - f1: 0.0182 - loss: 0.1299 - val_accuracy: 0.9773 - val_f1: 0.0169 - val_loss: 0.1109
# Epoch 4/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 74s 2ms/step - accuracy: 0.9796 - f1: 0.0157 - loss: 0.1600 - val_accuracy: 0.9778 - val_f1: 0.0169 - val_loss: 0.1112
# Epoch 5/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9805 - f1: 0.0167 - loss: 0.1340 - val_accuracy: 0.9788 - val_f1: 0.0176 - val_loss: 0.1059
# Epoch 6/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9819 - f1: 0.0179 - loss: 0.1277 - val_accuracy: 0.9754 - val_f1: 0.0164 - val_loss: 0.1140
# Epoch 7/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 82s 2ms/step - accuracy: 0.9785 - f1: 0.0166 - loss: 0.1323 - val_accuracy: 0.9855 - val_f1: 0.0231 - val_loss: 0.0944
# Epoch 8/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 81s 2ms/step - accuracy: 0.9857 - f1: 0.0212 - loss: 0.1445 - val_accuracy: 0.9854 - val_f1: 0.0229 - val_loss: 0.0917
# Epoch 9/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 80s 2ms/step - accuracy: 0.9807 - f1: 0.0178 - loss: 0.1560 - val_accuracy: 0.9846 - val_f1: 0.0229 - val_loss: 0.0922
# Epoch 10/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - accuracy: 0.9826 - f1: 0.0161 - loss: 0.1446 - val_accuracy: 0.9825 - val_f1: 0.0206 - val_loss: 0.0988
# Epoch 11/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9835 - f1: 0.0186 - loss: 0.1342 - val_accuracy: 0.9811 - val_f1: 0.0186 - val_loss: 0.1048
# Epoch 12/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9815 - f1: 0.0167 - loss: 0.1484 - val_accuracy: 0.9843 - val_f1: 0.0216 - val_loss: 0.0981
# Epoch 13/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9814 - f1: 0.0171 - loss: 0.1667 - val_accuracy: 0.9831 - val_f1: 0.0203 - val_loss: 0.0974
# Epoch 14/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9826 - f1: 0.0182 - loss: 0.1572 - val_accuracy: 0.9803 - val_f1: 0.0187 - val_loss: 0.1010
# Epoch 15/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9798 - f1: 0.0168 - loss: 0.1523 - val_accuracy: 0.9825 - val_f1: 0.0207 - val_loss: 0.0983
# Epoch 16/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9796 - f1: 0.0163 - loss: 0.1552 - val_accuracy: 0.9846 - val_f1: 0.0220 - val_loss: 0.0917
# Epoch 17/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9826 - f1: 0.0179 - loss: 0.1480 - val_accuracy: 0.9806 - val_f1: 0.0185 - val_loss: 0.1035
# Epoch 18/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - accuracy: 0.9825 - f1: 0.0146 - loss: 0.1656 - val_accuracy: 0.9760 - val_f1: 0.0164 - val_loss: 0.1111
# Epoch 19/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.9775 - f1: 0.0145 - loss: 0.1769 - val_accuracy: 0.9799 - val_f1: 0.0183 - val_loss: 0.1011
# Epoch 20/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 80s 2ms/step - accuracy: 0.9795 - f1: 0.0163 - loss: 0.1471 - val_accuracy: 0.9809 - val_f1: 0.0192 - val_loss: 0.0989
# Epoch 21/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9830 - f1: 0.0166 - loss: 0.1582 - val_accuracy: 0.9733 - val_f1: 0.0152 - val_loss: 0.1121
# Epoch 22/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9763 - f1: 0.0145 - loss: 0.1512 - val_accuracy: 0.9792 - val_f1: 0.0182 - val_loss: 0.1023
# Epoch 23/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9820 - f1: 0.0169 - loss: 0.1315 - val_accuracy: 0.9801 - val_f1: 0.0192 - val_loss: 0.1030
# Epoch 24/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9788 - f1: 0.0145 - loss: 0.1442 - val_accuracy: 0.9815 - val_f1: 0.0197 - val_loss: 0.0963
# Epoch 25/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 82s 2ms/step - accuracy: 0.9793 - f1: 0.0151 - loss: 0.1648 - val_accuracy: 0.9856 - val_f1: 0.0228 - val_loss: 0.0891
# Epoch 26/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9828 - f1: 0.0173 - loss: 0.1516 - val_accuracy: 0.9802 - val_f1: 0.0189 - val_loss: 0.1013
# Epoch 27/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9783 - f1: 0.0149 - loss: 0.1753 - val_accuracy: 0.9897 - val_f1: 0.0294 - val_loss: 0.0803
# Epoch 28/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9851 - f1: 0.0206 - loss: 0.1480 - val_accuracy: 0.9813 - val_f1: 0.0195 - val_loss: 0.1023
# Epoch 29/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9841 - f1: 0.0191 - loss: 0.1348 - val_accuracy: 0.9757 - val_f1: 0.0162 - val_loss: 0.1135
# Epoch 30/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9778 - f1: 0.0154 - loss: 0.1447 - val_accuracy: 0.9814 - val_f1: 0.0192 - val_loss: 0.1010
# Epoch 31/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.9844 - f1: 0.0192 - loss: 0.1345 - val_accuracy: 0.9814 - val_f1: 0.0200 - val_loss: 0.1018
# Epoch 32/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9793 - f1: 0.0149 - loss: 0.1616 - val_accuracy: 0.9842 - val_f1: 0.0216 - val_loss: 0.0956
# Epoch 33/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9779 - f1: 0.0149 - loss: 0.1779 - val_accuracy: 0.9836 - val_f1: 0.0218 - val_loss: 0.0874
# Epoch 34/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9830 - f1: 0.0197 - loss: 0.1682 - val_accuracy: 0.9859 - val_f1: 0.0236 - val_loss: 0.0898
# Epoch 35/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.9846 - f1: 0.0208 - loss: 0.1549 - val_accuracy: 0.9769 - val_f1: 0.0166 - val_loss: 0.1117
# Epoch 36/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9774 - f1: 0.0144 - loss: 0.1798 - val_accuracy: 0.9849 - val_f1: 0.0223 - val_loss: 0.0965
# Epoch 37/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 81s 2ms/step - accuracy: 0.9805 - f1: 0.0180 - loss: 0.1801 - val_accuracy: 0.9865 - val_f1: 0.0239 - val_loss: 0.0867
# Epoch 38/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9837 - f1: 0.0181 - loss: 0.1483 - val_accuracy: 0.9865 - val_f1: 0.0254 - val_loss: 0.0909
# Epoch 39/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9850 - f1: 0.0194 - loss: 0.1367 - val_accuracy: 0.9809 - val_f1: 0.0191 - val_loss: 0.1027
# Epoch 40/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9813 - f1: 0.0160 - loss: 0.1426 - val_accuracy: 0.9799 - val_f1: 0.0180 - val_loss: 0.1057
# Epoch 41/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.9813 - f1: 0.0166 - loss: 0.1612 - val_accuracy: 0.9771 - val_f1: 0.0167 - val_loss: 0.1125
# Epoch 42/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 83s 2ms/step - accuracy: 0.9764 - f1: 0.0154 - loss: 0.1641 - val_accuracy: 0.9839 - val_f1: 0.0215 - val_loss: 0.0976
# Epoch 43/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9809 - f1: 0.0178 - loss: 0.1663 - val_accuracy: 0.9799 - val_f1: 0.0183 - val_loss: 0.1056
# Epoch 44/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - accuracy: 0.9795 - f1: 0.0138 - loss: 0.1856 - val_accuracy: 0.9868 - val_f1: 0.0249 - val_loss: 0.0827
# Epoch 45/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9831 - f1: 0.0181 - loss: 0.1745 - val_accuracy: 0.9833 - val_f1: 0.0214 - val_loss: 0.0915
# Epoch 46/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9819 - f1: 0.0178 - loss: 0.1501 - val_accuracy: 0.9777 - val_f1: 0.0168 - val_loss: 0.1076
# Epoch 47/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 79s 2ms/step - accuracy: 0.9790 - f1: 0.0146 - loss: 0.1486 - val_accuracy: 0.9823 - val_f1: 0.0204 - val_loss: 0.0949
# Epoch 48/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.9806 - f1: 0.0163 - loss: 0.1493 - val_accuracy: 0.9819 - val_f1: 0.0193 - val_loss: 0.0970
# Epoch 49/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9823 - f1: 0.0178 - loss: 0.1328 - val_accuracy: 0.9778 - val_f1: 0.0173 - val_loss: 0.1078
# Epoch 50/50
# 20506/20506 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.9785 - f1: 0.0150 - loss: 0.1200 - val_accuracy: 0.9849 - val_f1: 0.0218 - val_loss: 0.0937

# %%
#oredição e métricas no conjunto de teste
y_prob = model.predict(X_test, batch_size=4096).ravel()
y_pred = (y_prob >= 0.5).astype(int)

acc = accuracy_score(y_test, y_pred)
f1  = f1_score(y_test, y_pred)

print(f"Accuracy (test) = {acc:.6f}")
print(f"F1-score (test) = {f1:.6f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Accuracy (test) = 0.984323
# F1-score (test) = 0.166200

# %% [markdown]
# como o F1 estava baixo, segue código para ajustar limiar para maximizar F1

# %%
from sklearn.metrics import precision_recall_curve
p, r, thr = precision_recall_curve(y_test, y_prob)
f1s = 2*p*r/(p+r+1e-12)
best_idx = np.nanargmax(f1s)
best_thr = thr[max(best_idx-1,0)]
y_pred_opt = (y_prob >= best_thr).astype(int)
print("Best threshold for F1:", best_thr)
print("F1@best_thr:", f1_score(y_test, y_pred_opt))
# Out:
# Best threshold for F1: 0.9996316
# F1@best_thr: 0.8059701492537313
